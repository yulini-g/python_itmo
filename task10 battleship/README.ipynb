# %% [markdown]
# # Морской бой
#
# Игра «Морской бой» против компьютера с графическим интерфейсом на PySide6. Три уровня сложности, таблица рекордов, настраиваемые параметры.
#
# ---
#
# ## Быстрый старт
#
# 1. Установите Python 3.8+
# 2. Установите зависимости: pip install PySide6
# 3. Запустите: python main.py
#
# ---
#
# ## Файлы
#
# - main.py — точка входа в приложение
# - gui/ — графический интерфейс
# - game/ — логика игры и ИИ
# - config.json — настройки (создаётся автоматически)
# - records.json — таблица рекордов (создаётся автоматически)
# - requirements.txt — зависимости
#
# ---
#
# ## Требования
#
# - Python 3.8+
# - PySide6
# - ОС: Windows 10/11, Linux
